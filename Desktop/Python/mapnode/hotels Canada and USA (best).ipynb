# %%
#http://geocommons.com/overlays/6720

import pandas as pd
import numpy as np
import scipy as sp
from mapnode import MapClient
client = MapClient(api_key='AjXDakgWGsf-NVH1pOIKY0PStr1RBH50QNHYBRpSLOZeBAa_ancvEGHTW1mVJTmr')
from pandas import DataFrame, Series

hotels = DataFrame.from_csv("/Users/LishaLi/Downloads/6720.csv")
hotels

#there is a good combination of rural and urban areas
# Out:
#         Longitude   Latitude  Rank  2006 Rank  \
# Score
# 83.91 -123.179800  49.193500     1         -1
# 83.95  -77.036524  38.900950     2         -1
# 83.95  -76.224765  38.790712     3         -1
# 91.09  -80.194732  33.028601    99         -1
# 84.02  -73.968740  40.766709     5         -1
# 85.42  -82.581764  35.611424    44         -1
# 84.07 -122.400741  37.792426     7         -1
# 89.64  -79.931327  32.780974    94         -1
# 85.66  -81.371731  30.217732    47         -1
# 88.57 -122.146801  47.732963    89         -1
# 84.20 -106.378394  39.642782    11         -1
# 84.27  -70.227926  43.567646    12         -1
# 88.52  -71.202621  46.814457    88         -1
# 85.75  -71.068157  42.352424    52         -1
# 85.79  -97.742235  30.262664    53         -1
# 85.24 -110.829659  43.586055    37         -1
# 87.76 -121.557798  45.709968    82         -1
# 84.55  -70.470636  43.379707    18         -1
# 84.76 -117.243433  32.904429    19         -1
# ...

# %%
hotel= pd.concat([hotels['Latitude'], hotels['Longitude']], axis=1)
